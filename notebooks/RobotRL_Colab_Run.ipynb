# %% [markdown]
# # RobotRL-Colab Run
#
# Chunked Colab runner for the RobotRF -> RARL -> RobotRL-Colab training workflow.

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# %cd /content
# !test -d RobotRL-Colab || git clone https://github.com/hojunjeon/RobotRL-Colab.git
# %cd /content/RobotRL-Colab
# !git pull --ff-only || true

# %%
DRIVE_ARTIFACT_ROOT = "/content/drive/MyDrive/RobotRL-Colab/artifacts"
DRY_RUN_DIR = "runs/colab/dry_run_stage1_strict_withdraw_seed7"
RUN_DIR = "runs/colab/run_001_stage1_strict_withdraw_seed7"
# !mkdir -p {DRIVE_ARTIFACT_ROOT} {DRY_RUN_DIR}

# %%
# !python -m pip install -U pip
# !python -m pip install -e '.[fetch]'
# !python -m robotrl.cli colab-preflight --output {DRY_RUN_DIR}/preflight.json --strict
# !python -m unittest discover -s tests

# %%
# !python -m robotrl.cli fetch-loop --dry-run --curriculum single-random-to-return --chunk-timesteps 50000 --n-envs 6 --learning-starts 10000 --checkpoint-interval 50000 --eval-episodes 20 --success-threshold 0.8 --seed 7 --visual-approval-timeout-seconds 1800 --visual-approval-poll-interval-seconds 30 --output-dir {DRY_RUN_DIR}
# !python -m robotrl.cli colab-sync --run-dir {DRY_RUN_DIR} --drive-artifact-root {DRIVE_ARTIFACT_ROOT}

# %%
# Start the fresh Colab baseline when the dry run looks right.
# !python -m robotrl.cli fetch-loop --curriculum single-random-to-return --chunk-timesteps 50000 --n-envs 6 --learning-starts 10000 --checkpoint-interval 50000 --eval-episodes 20 --success-threshold 0.8 --seed 7 --visual-approval-timeout-seconds 1800 --visual-approval-poll-interval-seconds 30 --output-dir {RUN_DIR}
# !python -m robotrl.cli colab-sync --run-dir {RUN_DIR} --drive-artifact-root {DRIVE_ARTIFACT_ROOT}
