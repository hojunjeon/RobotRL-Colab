# %% [markdown]
# # RobotRL-Colab Run\n\nChunked Colab runner for the RobotRF -> RARL -> RobotRL-Colab training workflow.\n

# %%
from google.colab import drive\ndrive.mount('/content/drive')\n

# %%
# %cd /content\n!test -d RobotRL-Colab || git clone https://github.com/hojunjeon/RobotRL-Colab.git\n%cd /content/RobotRL-Colab\n!git pull --ff-only || true\n

# %%
# !python -m pip install -U pip\n!python -m pip install -e '.[fetch]'\n!python -m unittest discover -s tests\n

# %%
# !python -m robotrl.cli fetch-loop --dry-run --curriculum single-random-to-return --chunk-timesteps 50000 --n-envs 6 --learning-starts 10000 --checkpoint-interval 50000 --eval-episodes 20 --success-threshold 0.8 --seed 7 --visual-approval-timeout-seconds 1800 --visual-approval-poll-interval-seconds 30 --output-dir runs/colab/dry_run_stage1_strict_withdraw_seed7\n

# %%
# Start the fresh Colab baseline when the dry run looks right.\n# !python -m robotrl.cli fetch-loop --curriculum single-random-to-return --chunk-timesteps 50000 --n-envs 6 --learning-starts 10000 --checkpoint-interval 50000 --eval-episodes 20 --success-threshold 0.8 --seed 7 --visual-approval-timeout-seconds 1800 --visual-approval-poll-interval-seconds 30 --output-dir runs/colab/run_001_stage1_strict_withdraw_seed7\n
